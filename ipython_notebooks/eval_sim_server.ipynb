# %%
import numpy as np
import pickle
import os

# %%
path = os.getcwd()
os.listdir(path+'/results_simulation_2017-12-03T14:26:04.093421')
# Out:
# ['logisticsampler_HMC_L_random_rep_27_dim_10.p',
#  'logisticsampler_RW_rep_7_dim_10.p',
#  'logisticsampler_HMC_rep_26_dim_10.p',
#  'logisticsampler_MALA_rep_12_dim_10.p',
#  'logisticsampler_MALA_rep_7_dim_10.p',
#  'logisticsampler_HMC_rep_33_dim_10.p',
#  'logisticsampler_RW_rep_1_dim_10.p',
#  'logisticsampler_MALA_rep_2_dim_10.p',
#  'logisticsampler_MALA_rep_20_dim_10.p',
#  'logisticsampler_HMC_rep_16_dim_10.p',
#  'logisticsampler_RW_rep_18_dim_10.p',
#  'logisticsampler_RW_rep_27_dim_10.p',
#  'logisticsampler_RW_rep_21_dim_10.p',
#  'logisticsampler_HMC_rep_8_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_25_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_11_dim_10.p',
#  'logisticsampler_MALA_rep_19_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_37_dim_10.p',
#  'logisticsampler_MALA_rep_17_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_26_dim_10.p',
#  'logisticsampler_MALA_rep_39_dim_10.p',
#  'logisticsampler_MALA_rep_8_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_32_dim_10.p',
#  'logisticsampler_RW_rep_32_dim_10.p',
#  'logisticsampler_MALA_rep_31_dim_10.p',
#  'logisticsampler_HMC_rep_1_dim_10.p',
#  'logisticsampler_MALA_rep_36_dim_10.p',
#  'logisticsampler_HMC_rep_22_dim_10.p',
#  'logisticsampler_RW_rep_29_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_33_dim_10.p',
#  'logisticsampler_HMC_rep_15_dim_10.p',
#  'logisticsampler_MALA_rep_26_dim_10.p',
#  'logisticsampler_MALA_rep_22_dim_10.p',
#  'logisticsampler_RW_rep_30_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_9_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_24_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_7_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_17_dim_10.p',
#  'logisticsampler_MALA_rep_16_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_36_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_13_dim_10.p',
#  'logisticsampler_HMC_rep_10_dim_10.p',
#  'logisticsampler_RW_rep_11_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_14_dim_10.p',
#  'logisticsampler_HMC_rep_30_dim_10.p',
#  'logisticsampler_RW_rep_37_dim_10.p',
#  'logisticsampler_HMC_rep_12_dim_10.p',
#  'logisticsampler_HMC_rep_31_dim_10.p',
#  'logisticsampler_HMC_rep_2_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_30_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_12_dim_10.p',
#  'logisticsampler_HMC_rep_17_dim_10.p',
#  'logisticsampler_RW_rep_4_dim_10.p',
#  'logisticsampler_HMC_rep_14_dim_10.p',
#  'logisticsampler_HMC_rep_24_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_6_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_2_dim_10.p',
#  'logisticsampler_HMC_rep_39_dim_10.p',
#  'logisticsampler_MALA_rep_15_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_31_dim_10.p',
#  'logisticsampler_HMC_rep_19_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_20_dim_10.p',
#  'logisticsampler_HMC_rep_13_dim_10.p',
#  'logisticsampler_RW_rep_9_dim_10.p',
#  'logisticsampler_MALA_rep_34_dim_10.p',
#  'logisticsampler_HMC_rep_36_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_16_dim_10.p',
#  'logisticsampler_HMC_rep_37_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_3_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_29_dim_10.p',
#  'logisticsampler_MALA_rep_14_dim_10.p',
#  'logisticsampler_HMC_rep_23_dim_10.p',
#  'logisticsampler_HMC_rep_38_dim_10.p',
#  'logisticsampler_RW_rep_10_dim_10.p',
#  'logisticsampler_RW_rep_16_dim_10.p',
#  'logisticsampler_MALA_rep_10_dim_10.p',
#  'logisticsampler_RW_rep_2_dim_10.p',
#  'logisticsampler_HMC_rep_28_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_22_dim_10.p',
#  'logisticsampler_HMC_rep_34_dim_10.p',
#  'logisticsampler_RW_rep_15_dim_10.p',
#  'logisticsampler_RW_rep_28_dim_10.p',
#  'logisticsampler_MALA_rep_4_dim_10.p',
#  'logisticsampler_MALA_rep_28_dim_10.p',
#  'logisticsampler_MALA_rep_35_dim_10.p',
#  'logisticsampler_RW_rep_22_dim_10.p',
#  'logisticsampler_HMC_rep_7_dim_10.p',
#  'logisticsampler_MALA_rep_27_dim_10.p',
#  'logisticsampler_RW_rep_13_dim_10.p',
#  'logisticsampler_MALA_rep_23_dim_10.p',
#  'logisticsampler_HMC_rep_20_dim_10.p',
#  'logisticsampler_MALA_rep_13_dim_10.p',
#  'logisticsampler_MALA_rep_18_dim_10.p',
#  'logisticsampler_RW_rep_39_dim_10.p',
#  'logisticsampler_HMC_rep_11_dim_10.p',
#  'logisticsampler_HMC_rep_27_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_15_dim_10.p',
#  'logisticsampler_MALA_rep_11_dim_10.p',
#  'logisticsampler_RW_rep_0_dim_10.p',
#  'logisticsampler_RW_rep_35_dim_10.p',
#  'logisticsampler_RW_rep_8_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_23_dim_10.p',
#  'logisticsampler_MALA_rep_29_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_4_dim_10.p',
#  'logisticsampler_MALA_rep_33_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_38_dim_10.p',
#  'logisticsampler_HMC_rep_35_dim_10.p',
#  'logisticsampler_HMC_rep_3_dim_10.p',
#  'logisticsampler_RW_rep_23_dim_10.p',
#  'logisticsampler_RW_rep_20_dim_10.p',
#  'logisticsampler_RW_rep_36_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_35_dim_10.p',
#  'logisticsampler_HMC_rep_9_dim_10.p',
#  'logisticsampler_RW_rep_38_dim_10.p',
#  'logisticsampler_RW_rep_25_dim_10.p',
#  'logisticsampler_RW_rep_6_dim_10.p',
#  'logisticsampler_HMC_rep_4_dim_10.p',
#  'logisticsampler_MALA_rep_24_dim_10.p',
#  'logisticsampler_RW_rep_3_dim_10.p',
#  'logisticsampler_RW_rep_24_dim_10.p',
#  'logisticsampler_HMC_rep_18_dim_10.p',
#  'logisticsampler_RW_rep_17_dim_10.p',
#  'logisticsampler_RW_rep_26_dim_10.p',
#  'logisticsampler_HMC_rep_29_dim_10.p',
#  'logisticsampler_HMC_rep_25_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_18_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_0_dim_10.p',
#  'logisticsampler_MALA_rep_1_dim_10.p',
#  'logisticsampler_HMC_rep_0_dim_10.p',
#  'logisticsampler_RW_rep_5_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_1_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_5_dim_10.p',
#  'logisticsampler_HMC_rep_21_dim_10.p',
#  'logisticsampler_MALA_rep_37_dim_10.p',
#  'logisticsampler_RW_rep_33_dim_10.p',
#  'logisticsampler_MALA_rep_9_dim_10.p',
#  'logisticsampler_MALA_rep_0_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_8_dim_10.p',
#  'logisticsampler_MALA_rep_30_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_21_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_34_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_39_dim_10.p',
#  'logisticsampler_HMC_rep_32_dim_10.p',
#  'logisticsampler_MALA_rep_38_dim_10.p',
#  'logisticsampler_HMC_rep_6_dim_10.p',
#  'logisticsampler_MALA_rep_25_dim_10.p',
#  'logisticsampler_RW_rep_12_dim_10.p',
#  'logisticsampler_MALA_rep_32_dim_10.p',
#  'logisticsampler_MALA_rep_6_dim_10.p',
#  'logisticsampler_MALA_rep_5_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_28_dim_10.p',
#  'logisticsampler_MALA_rep_3_dim_10.p',
#  'logisticsampler_RW_rep_34_dim_10.p',
#  'logisticsampler_MALA_rep_21_dim_10.p',
#  'logisticsampler_RW_rep_14_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_19_dim_10.p',
#  'logisticall_dict_sampler_dim_10.p',
#  'logisticsampler_HMC_L_random_rep_10_dim_10.p',
#  'logisticsampler_HMC_rep_5_dim_10.p',
#  'logisticsampler_RW_rep_19_dim_10.p',
#  'logisticsampler_RW_rep_31_dim_10.p']

# %%
#studentall_dict_sampler = pickle.load(file=open('studentall_dict_sampler.p', "rb"))
os.chdir(path+'/results_simulation_2017-12-03T14:26:04.093421')
studentall_dict_sampler = pickle.load(file=open('logisticall_dict_sampler_dim_10.p', "rb"))
os.chdir(path)
#studentall_dict_sampler_dim_10.p
#studentrw_dict_sampler = pickle.load(file=open('studentsampler_RW_rep_4_dim_2.p', "rb"))

# %%
from smc_sampler_functions.functions_smc_plotting import plot_repeated_simulations
plot_repeated_simulations(studentall_dict_sampler)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
studentrw_dict_sampler['perf_list']
# Out:
# [{'acceptance_rate': 0.650390625,
#   'energy': array([-0.84574628,  0.86599236, -1.83268973, ..., -0.18911854,
#           0.13051107, -3.93490346]),
#   'epsilon': array([[ 0.73223595],
#          [ 0.92049885],
#          [ 0.85099051],
#          ...,
#          [ 0.99865468],
#          [ 0.15536167],
#          [ 0.84698942]]),
#   'squarejumpdist': array([ 1.00506966,  1.83845344,  1.07441005, ...,  0.48728635,
#           0.01252154,  3.8571127 ]),
#   'squarejumpdist_realized': array([ 0.        ,  1.83845344,  0.        , ...,  0.48728635,
#           0.01252154,  0.        ])},
#  {'acceptance_rate': 0.572265625,
#   'energy': array([-0.17086567, -2.90180218, -1.99832713, ..., -3.26935461,
#           0.03796823,  0.45549136]),
#   'epsilon': array([[ 0.3089817 ],
#          [ 1.54716229],
#          [ 1.29115229],
#          ...,
#          [ 1.50326084],
#          [ 0.97029865],
#          [ 1.11694073]]),
#   'squarejumpdist': array([ 0.03671489,  6.22851216,  2.37303755, ...,  3.89671503,
#           0.23337529,  0.15000476]),
#   'squarejumpdist_realized': array([ 0.03671489,  0.        ,  0.        , ...,  0.        ,
#           0.23337529,  0.15000476])},
#  {'acceptance_rate': 0.5546875,
#   'energy': array([-5.5589046 , -2.34926658, -1.91049352, ..., -0.61642515,
#           1.13261085,  0.41566203]),
#   'epsilon': array([[ 2.12879289],
#          [ 1.88752263],
#          [ 1.34036495],
#          ...,
#          [ 0.82380418],
#          [ 1.1387731 ],
#          [ 2.12879289]]),
#   'squarejumpdist': array([ 12.6707788 ,  12.86046276,   4.32023297, ...,   0.15414209,
#            4.93040627,   1.07808972]),
#   'squarejumpdist_realized': array([ 0.        ,  0.        ,  0.        , ...,  0.15414209,
#           4.93040627,  1.07808972])},
#  {'acceptance_rate': 0.53125,
#   'energy': array([-0.51693542, -1.25717892, -0.94494636, ..., -5.22083817,
#           0.24268556, -2.87255243]),
#   'epsilon': array([[ 0.99819995],
#          [ 1.25789487],
#          [ 1.76748715],
#          ...,
#          [ 2.6939311 ],
#          [ 2.02482672],
#          [ 2.38408834]]),
#   'squarejumpdist': array([  0.43786676,   1.64558855,  12.09809068, ...,   7.85903612,
#            0.14794182,  10.34231573]),
#   'squarejumpdist_realized': array([ 0.43786676,  0.        ,  0.        , ...,  0.        ,
#           0.14794182,  0.        ])},
#  {'acceptance_rate': 0.5029296875,
#   'energy': array([-3.25653417, -0.17043072, -1.75285352, ..., -0.52088789,
#           0.33253194,  0.14821984]),
#   'epsilon': array([[ 1.51004266],
#          [ 0.59963282],
#          [ 2.10048217],
#          ...,
#          [ 1.57819961],
#          [ 1.14194038],
#          [ 1.79318317]]),
#   'squarejumpdist': array([ 2.84539076,  0.1757292 ,  7.25914196, ...,  5.04481359,
#           0.53740611,  3.94462624]),
#   'squarejumpdist_realized': array([ 0.        ,  0.1757292 ,  0.        , ...,  5.04481359,
#           0.53740611,  3.94462624])},
#  {'acceptance_rate': 0.50390625,
#   'energy': array([-0.58821841, -1.17674019, -0.65973866, ..., -1.30572635,
#          -2.58004047,  2.82204503]),
#   'epsilon': array([[ 0.68001199],
#          [ 2.75929409],
#          [ 3.50486778],
#          ...,
#          [ 2.2772099 ],
#          [ 2.06221126],
#          [ 2.36522284]]),
#   'squarejumpdist': array([ 0.67459404,  2.80719155,  4.15838053, ...,  5.13805908,
#           6.6386252 ,  8.30302233]),
#   'squarejumpdist_realized': array([ 0.        ,  2.80719155,  4.15838053, ...,  0.        ,
#           0.        ,  8.30302233])},
#  {'acceptance_rate': 0.4853515625,
#   'energy': array([ 0.64952106, -3.7698761 , -7.6832059 , ..., -0.54022734,
#           0.0356064 , -1.09990047]),
#   'epsilon': array([[ 1.21050217],
#          [ 3.52534597],
#          [ 3.78083576],
#          ...,
#          [ 4.15224545],
#          [ 4.18278512],
#          [ 2.9648654 ]]),
#   'squarejumpdist': array([  1.42928981,  15.33090343,  17.08137558, ...,  11.90671825,
#            4.88123915,   4.18742921]),
#   'squarejumpdist_realized': array([  1.42928981,   0.        ,   0.        , ...,  11.90671825,
#            4.88123915,   4.18742921])},
#  {'acceptance_rate': 0.4052734375,
#   'energy': array([-1.73504089, -7.92036425, -1.66760762, ..., -0.64207964,
#          -0.48233466, -3.17815463]),
#   'epsilon': array([[ 1.49627696],
#          [ 2.18250552],
#          [ 2.44095506],
#          ...,
#          [ 2.03634054],
#          [ 3.10604873],
#          [ 3.1060547 ]]),
#   'squarejumpdist': array([  3.26786364,  13.32094181,   1.68140331, ...,   1.39323983,
#            0.47874101,   9.18862362]),
#   'squarejumpdist_realized': array([ 0.,  0.,  0., ...,  0.,  0.,  0.])},
#  {'acceptance_rate': 0.39453125,
#   'energy': array([ -2.28191655, -11.8358334 ,  -1.58480733, ...,  -4.17613207,
#            0.19085272,  -6.2491787 ]),
#   'epsilon': array([[ 4.1821047 ],
#          [ 3.61308664],
#          [ 2.85342456],
#          ...,
#          [ 3.88488012],
#          [ 3.62568815],
#          [ 3.90627975]]),
#   'squarejumpdist': array([ 21.44437779,  16.48288781,   2.06687161, ...,  17.75725318,
#            0.54826355,  22.13476634]),
#   'squarejumpdist_realized': array([ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.54826355,  0.        ])},
#  {'acceptance_rate': 0.3603515625,
#   'energy': array([  3.07702887,  -1.34859488,  -3.31497491, ..., -14.00167677,
#            0.12950909, -17.907922  ]),
#   'epsilon': array([[ 2.45209085],
#          [ 2.41143371],
#          [ 3.4812751 ],
#          ...,
#          [ 2.45289992],
#          [ 0.7876002 ],
#          [ 3.01729149]]),
#   'squarejumpdist': array([  7.9093871 ,   1.58381396,  15.0824204 , ...,  14.14773907,
#            0.05150346,  33.9136045 ]),
#   'squarejumpdist_realized': array([ 7.9093871 ,  0.        ,  0.        , ...,  0.        ,
#           0.05150346,  0.        ])},
#  {'acceptance_rate': 0.35546875,
#   'energy': array([-1.39387329, -3.69294237,  1.09016287, ...,  1.17242432,
#          -2.52951642, -0.56533483]),
#   'epsilon': array([[ 2.33641041],
#          [ 1.38952597],
#          [ 1.48706985],
#          ...,
#          [ 1.85509474],
#          [ 2.8427349 ],
#          [ 0.71500494]]),
#   'squarejumpdist': array([  1.9702605 ,  13.16969583,   0.48873483, ...,   4.86527076,
#           13.6879297 ,   0.70928467]),
#   'squarejumpdist_realized': array([ 0.        ,  0.        ,  0.48873483, ...,  4.86527076,
#           0.        ,  0.        ])},
#  {'acceptance_rate': 0.3173828125,
#   'energy': array([-10.50590463,  -0.63622567,   0.14612978, ...,   0.04872567,
#           -0.95460846,  -4.53919879]),
#   'epsilon': array([[ 1.92664482],
#          [ 0.75905306],
#          [ 0.58813157],
#          ...,
#          [ 0.53219763],
#          [ 1.24980012],
#          [ 1.52960355]]),
#   'squarejumpdist': array([  1.73917007e+01,   2.60416230e-01,   8.78761318e-02, ...,
#            9.28442716e-04,   1.59494665e+00,   1.61256217e+01]),
#   'squarejumpdist_realized': array([ 0.        ,  0.26041623,  0.08787613, ...,  0.00092844,
#           0.        ,  0.        ])},
#  {'acceptance_rate': 0.298828125,
#   'energy': array([-3.28635979,  0.23704772, -2.04204257, ...,  0.48764018,
#           0.54146193,  0.33433977]),
#   'epsilon': array([[ 0.51757581],
#          [ 0.29112837],
#          [ 0.59293459],
#          ...,
#          [ 1.1130956 ],
#          [ 0.49580716],
#          [ 0.82492897]]),
#   'squarejumpdist': array([ 1.10204911,  0.09593352,  1.68996945, ...,  1.5731641 ,
#           0.05849778,  1.51822834]),
#   'squarejumpdist_realized': array([ 0.        ,  0.09593352,  0.        , ...,  1.5731641 ,
#           0.05849778,  1.51822834])},
#  {'acceptance_rate': 0.2900390625,
#   'energy': array([-1.97440736, -1.35202513, -0.57696646, ..., -4.33776978,
#          -2.2966866 , -2.0105261 ]),
#   'epsilon': array([[ 0.29465071],
#          [ 0.36818246],
#          [ 0.67430153],
#          ...,
#          [ 0.54482436],
#          [ 0.32770185],
#          [ 0.62715615]]),
#   'squarejumpdist': array([ 0.80119604,  0.46669356,  0.04595487, ...,  1.27901318,
#           1.80240859,  0.27719599]),
#   'squarejumpdist_realized': array([ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           1.80240859,  0.27719599])},
#  {'acceptance_rate': 0.3046875,
#   'energy': array([-4.85021209, -3.13448613, -7.42869622, ..., -5.05745868,
#          -0.28942095, -3.11532767]),
#   'epsilon': array([[ 0.50294848],
#          [ 0.52369044],
#          [ 0.42726353],
#          ...,
#          [ 0.50621763],
#          [ 0.27563926],
#          [ 0.32778006]]),
#   'squarejumpdist': array([ 2.03904772,  3.14073558,  3.37084244, ...,  6.08281861,
#           0.26495585,  0.5043274 ]),
#   'squarejumpdist_realized': array([ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.26495585,  0.        ])},
#  {'acceptance_rate': 0.37109375,
#   'energy': array([-1.3651257 , -3.32503142, -4.89115405, ..., -1.09054817,
#          -1.68534509,  1.39039744]),
#   'epsilon': array([[ 0.36763677],
#          [ 0.28755058],
#          [ 0.3161622 ],
#          ...,
#          [ 0.27060126],
#          [ 0.27060126],
#          [ 0.1653652 ]]),
#   'squarejumpdist': array([ 0.40306863,  0.63846776,  1.9880294 , ...,  0.16306442,
#           0.53966953,  0.12153512]),
#   'squarejumpdist_realized': array([ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  0.12153512])}]
